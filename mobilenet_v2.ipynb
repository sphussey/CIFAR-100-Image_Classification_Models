# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import os
from datetime import datetime
import pytz
from pathlib import Path
import sklearn as sk
import tensorflow as tf
import torch
import torch.nn as nn
from torchvision.io import read_image
import time
import timeit
import random
import torchvision.models as models
from torchvision.datasets import CIFAR100
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as transforms
import sklearn.metrics
import csv
import timeit

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls 'drive/MyDrive/DS5220: Final Project/logs/mobilenet_v2'
# Out:
# 20240425_192621_logs/  20240425_205041_logs/  20240425_212853_logs/  20240425_215918_logs/

# %%
BASE_LOGS_PATH = 'drive/MyDrive/DS5220: Final Project/logs/mobilenet_v2'

# %%
# https://pytorch.org/docs/stable/notes/mps.html
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
CIFAR100_ROOT_PATH='drive/MyDrive/DS5220: Final Project'

class Cifar100():
    def __init__(self,
                 calculate_mean_and_std = False):
        if calculate_mean_and_std:
            self.mean, self.std = self.calculate_mean_and_std()
        else:
            self.mean, self.std = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

        self.BATCH_SIZE = 128
        self.transform = transforms.Compose(
            [transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)])

        self.train_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                download=True,
                                train=True,
                                transform=self.transform)

        self.eval_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                train=False,
                                transform=self.transform)

        self.train_data_loader = DataLoader(dataset=self.train_dataset,
                               num_workers=0,
                               batch_size=self.BATCH_SIZE,
                               shuffle=True)

        self.eval_data_loader = DataLoader(dataset=self.eval_dataset,
                              num_workers=0,
                              batch_size=self.BATCH_SIZE,
                              shuffle=False)

    def calculate_mean_and_std(self):
        train_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                download=True,
                                train=True)
        x = np.concatenate([np.asarray(train_dataset[i][0]) for i in range(len(train_dataset))])
        _mean = np.mean(x, axis=(0, 1))/255
        _std = np.std(x, axis=(0, 1))/255
        _mean = _mean.tolist()
        _std = _std.tolist()
        return _mean, _std

class Cifar100WithAugmentation():
    def __init__(self, calculate_mean_and_std=False):
        CIFAR100_ROOT_PATH = 'drive/MyDrive/DS5220: Final Project'
        if calculate_mean_and_std:
            self.mean, self.std = self.calculate_mean_and_std()
        else:
            self.mean, self.std = (0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)
        self.BATCH_SIZE = 128
        self.train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)
        ])

        self.eval_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)
        ])

        self.train_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                               download=True,
                                               train=True,
                                               transform=self.train_transform)

        self.eval_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                              train=False,
                                              transform=self.eval_transform)

        self.train_data_loader = DataLoader(dataset=self.train_dataset,
                                            num_workers=4,
                                            batch_size=self.BATCH_SIZE,
                                            shuffle=True)

        self.eval_data_loader = DataLoader(dataset=self.eval_dataset,
                                           num_workers=4,
                                           batch_size=self.BATCH_SIZE,
                                           shuffle=False)

    def calculate_mean_and_std(self):
        train_dataset = CIFAR100(root='drive/MyDrive/DS5220: Final Project',
                                          download=True,
                                          train=True)
        x = np.concatenate([np.asarray(train_dataset[i][0]) for i in range(len(train_dataset))])
        mean = np.mean(x, axis=(0, 1)) / 255
        std = np.std(x, axis=(0, 1)) / 255
        return mean.tolist(), std.tolist()

cf100 = Cifar100(calculate_mean_and_std=True)
cf100_w_aug = Cifar100WithAugmentation(calculate_mean_and_std=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# mobilenetv2 model config
config = {
    'dataloader' : cf100_w_aug,
    'model': models.mobilenet_v2(),
    'epochs': 70,
    'optimizer': 'SGD',
    'learning_rate': 0.01,
    'momentum': 0.9,
    'weight_decay': 5e-4,
    'loss': nn.CrossEntropyLoss(),
    'log_dir': os.path.join(BASE_LOGS_PATH, time.strftime('%Y%m%d_%H%M%S') + '_logs'),
    'device' : device,
    'run_time': None,
    'drop-out': False
}

model = config['model']
model.to(device)
EPOCHS = config['epochs']
criterion = config['loss']
optimizer = torch.optim.SGD(model.parameters(),
                            lr=config['learning_rate'],
                            momentum=config['momentum'],
                            weight_decay=config['weight_decay'])

#  log directory
if not os.path.exists(config['log_dir']):
    os.makedirs(config['log_dir'])
    print(f"Directory '{config['log_dir']}' created")
else:
    print(f"Directory '{config['log_dir']}' already exists")

metrics_path = os.path.join(config['log_dir'], 'training_metrics.csv')
with open(metrics_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write the header row
    writer.writerow(['Epoch', 'Train Loss', 'Train Accuracy', 'Eval Loss', 'Eval Accuracy', 'Top-1 Accuracy', 'Top-5 Accuracy', 'Epoch Time (seconds)'])
    training_start_time = timeit.default_timer()
    for epoch in range(config['epochs']):
        start_time = timeit.default_timer()
        train_losses = []
        train_accuracies = []

        model.train()
        for images, labels in config['dataloader'].train_data_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())
            _, predicted = torch.max(outputs, 1)
            accuracy = (predicted == labels).float().mean().item()
            train_accuracies.append(accuracy)

        eval_losses = []
        eval_accuracies = []
        top1_accuracies = []
        top5_accuracies = []
        model.eval()
        with torch.no_grad():
            for images, labels in config['dataloader'].eval_data_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                eval_losses.append(loss.item())

                #  top-1 accuracy
                _, predicted = torch.max(outputs, 1)
                top1_accuracy = (predicted == labels).float().mean().item()
                top1_accuracies.append(top1_accuracy)

                #  top-5 accuracy
                _, top5_preds = outputs.topk(5, dim=1)
                top5_correct = top5_preds.eq(labels.view(-1, 1).expand_as(top5_preds))
                top5_accuracy = top5_correct.float().sum(1).ge(1).float().mean().item()
                top5_accuracies.append(top5_accuracy)

                eval_accuracies.append(top1_accuracy)
        # write training  to csv
        end_time = timeit.default_timer()
        epoch_duration = end_time - start_time
        writer.writerow([
            epoch + 1,
            np.mean(train_losses),
            np.mean(train_accuracies) * 100,
            np.mean(eval_losses),
            np.mean(eval_accuracies) * 100,
            np.mean(top1_accuracies) * 100,
            np.mean(top5_accuracies) * 100,
            epoch_duration
        ])
        print(f"Epoch {epoch+1}/{config['epochs']}")
        print(f"Train Loss: {np.mean(train_losses):.4f}, Train Accuracy: {np.mean(train_accuracies) * 100:.2f}%")
        print(f"Eval Loss: {np.mean(eval_losses):.4f}, Eval Accuracy: {np.mean(eval_accuracies) * 100:.2f}%, Top-1 Accuracy: {np.mean(top1_accuracies) * 100:.2f}%, Top-5 Accuracy: {np.mean(top5_accuracies) * 100:.2f}%")
    training_end_time = timeit.default_timer()
    training_duration = training_end_time - training_start_time
    config['run_time'] = training_duration

config_path = os.path.join(config['log_dir'], 'config.txt')
# output config file to directory
with open(config_path, 'w') as f:
    for key, value in config.items():
        f.write(f'{key}: {value}\n')

torch.save(model.state_dict(), os.path.join(config['log_dir'], 'model_state_dict.pth'))
torch.save(model, os.path.join(config['log_dir'], 'complete_model.pth'))
# Out:
# Directory 'drive/MyDrive/DS5220: Final Project/logs/mobilenet_v2/20240426_193309_logs' created
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1/70
# Train Loss: 4.3493, Train Accuracy: 5.83%
# Eval Loss: 3.8677, Eval Accuracy: 9.87%, Top-1 Accuracy: 9.87%, Top-5 Accuracy: 30.67%
# Epoch 2/70
# Train Loss: 3.7674, Train Accuracy: 11.53%
# Eval Loss: 3.5640, Eval Accuracy: 14.89%, Top-1 Accuracy: 14.89%, Top-5 Accuracy: 40.86%
# Epoch 3/70
# Train Loss: 3.5610, Train Accuracy: 14.64%
# Eval Loss: 3.4469, Eval Accuracy: 16.61%, Top-1 Accuracy: 16.61%, Top-5 Accuracy: 43.37%
# Epoch 4/70
# Train Loss: 3.4098, Train Accuracy: 17.43%
# Eval Loss: 3.2627, Eval Accuracy: 19.77%, Top-1 Accuracy: 19.77%, Top-5 Accuracy: 48.30%
# Epoch 5/70
# Train Loss: 3.2811, Train Accuracy: 19.54%
# Eval Loss: 3.1760, Eval Accuracy: 21.62%, Top-1 Accuracy: 21.62%, Top-5 Accuracy: 50.68%
# Epoch 6/70
# Train Loss: 3.1672, Train Accuracy: 21.89%
# Eval Loss: 3.1531, Eval Accuracy: 22.20%, Top-1 Accuracy: 22.20%, Top-5 Accuracy: 51.93%
# Epoch 7/70
# Train Loss: 3.0580, Train Accuracy: 23.89%
# Eval Loss: 2.9803, Eval Accuracy: 26.17%, Top-1 Accuracy: 26.17%, Top-5 Accuracy: 55.46%
# Epoch 8/70
# Train Loss: 2.9712, Train Accuracy: 25.26%
# Eval Loss: 2.9325, Eval Accuracy: 26.54%, Top-1 Accuracy: 26.54%, Top-5 Accuracy: 57.67%
# Epoch 9/70
# Train Loss: 2.8865, Train Accuracy: 26.77%
# Eval Loss: 2.8392, Eval Accuracy: 28.17%, Top-1 Accuracy: 28.17%, Top-5 Accuracy: 59.33%
# Epoch 10/70
# Train Loss: 2.7997, Train Accuracy: 28.57%
# Eval Loss: 2.7590, Eval Accuracy: 30.47%, Top-1 Accuracy: 30.47%, Top-5 Accuracy: 61.43%
# Epoch 11/70
# Train Loss: 2.7360, Train Accuracy: 29.93%
# Eval Loss: 2.6880, Eval Accuracy: 31.70%, Top-1 Accuracy: 31.70%, Top-5 Accuracy: 62.61%
# Epoch 12/70
# Train Loss: 2.6721, Train Accuracy: 30.78%
# Eval Loss: 2.6612, Eval Accuracy: 32.41%, Top-1 Accuracy: 32.41%, Top-5 Accuracy: 63.57%
# Epoch 13/70
# Train Loss: 2.6085, Train Accuracy: 32.41%
# Eval Loss: 2.6234, Eval Accuracy: 32.93%, Top-1 Accuracy: 32.93%, Top-5 Accuracy: 63.57%
# Epoch 14/70
# Train Loss: 2.5518, Train Accuracy: 33.30%
# Eval Loss: 2.5962, Eval Accuracy: 33.89%, Top-1 Accuracy: 33.89%, Top-5 Accuracy: 64.69%
# Epoch 15/70
# Train Loss: 2.4834, Train Accuracy: 34.83%
# Eval Loss: 2.5855, Eval Accuracy: 33.38%, Top-1 Accuracy: 33.38%, Top-5 Accuracy: 64.92%
# Epoch 16/70
# Train Loss: 2.4464, Train Accuracy: 35.73%
# Eval Loss: 2.6109, Eval Accuracy: 33.10%, Top-1 Accuracy: 33.10%, Top-5 Accuracy: 64.28%
# Epoch 17/70
# Train Loss: 2.3949, Train Accuracy: 36.68%
# Eval Loss: 2.4638, Eval Accuracy: 35.74%, Top-1 Accuracy: 35.74%, Top-5 Accuracy: 67.96%
# Epoch 18/70
# Train Loss: 2.3498, Train Accuracy: 37.44%
# Eval Loss: 2.4245, Eval Accuracy: 37.12%, Top-1 Accuracy: 37.12%, Top-5 Accuracy: 68.14%
# Epoch 19/70
# Train Loss: 2.3107, Train Accuracy: 38.40%
# Eval Loss: 2.3991, Eval Accuracy: 37.42%, Top-1 Accuracy: 37.42%, Top-5 Accuracy: 69.20%
# Epoch 20/70
# Train Loss: 2.2682, Train Accuracy: 38.98%
# Eval Loss: 2.4121, Eval Accuracy: 36.53%, Top-1 Accuracy: 36.53%, Top-5 Accuracy: 68.84%
# Epoch 21/70
# Train Loss: 2.2315, Train Accuracy: 39.98%
# Eval Loss: 2.3594, Eval Accuracy: 38.48%, Top-1 Accuracy: 38.48%, Top-5 Accuracy: 69.85%
# Epoch 22/70
# Train Loss: 2.1899, Train Accuracy: 40.79%
# Eval Loss: 2.3439, Eval Accuracy: 38.58%, Top-1 Accuracy: 38.58%, Top-5 Accuracy: 70.39%
# Epoch 23/70
# Train Loss: 2.1593, Train Accuracy: 41.41%
# Eval Loss: 2.3613, Eval Accuracy: 38.56%, Top-1 Accuracy: 38.56%, Top-5 Accuracy: 70.21%
# Epoch 24/70
# Train Loss: 2.1203, Train Accuracy: 42.62%
# Eval Loss: 2.3842, Eval Accuracy: 38.18%, Top-1 Accuracy: 38.18%, Top-5 Accuracy: 70.15%
# Epoch 25/70
# Train Loss: 2.0857, Train Accuracy: 43.07%
# Eval Loss: 2.4031, Eval Accuracy: 37.85%, Top-1 Accuracy: 37.85%, Top-5 Accuracy: 69.65%
# Epoch 26/70
# Train Loss: 2.0510, Train Accuracy: 44.03%
# Eval Loss: 2.2879, Eval Accuracy: 40.25%, Top-1 Accuracy: 40.25%, Top-5 Accuracy: 72.20%
# Epoch 27/70
# Train Loss: 2.0283, Train Accuracy: 44.74%
# Eval Loss: 2.2535, Eval Accuracy: 40.51%, Top-1 Accuracy: 40.51%, Top-5 Accuracy: 72.53%
# Epoch 28/70
# Train Loss: 1.9821, Train Accuracy: 45.64%
# Eval Loss: 2.2390, Eval Accuracy: 41.26%, Top-1 Accuracy: 41.26%, Top-5 Accuracy: 72.72%
# Epoch 29/70
# Train Loss: 1.9690, Train Accuracy: 45.70%
# Eval Loss: 2.2316, Eval Accuracy: 41.65%, Top-1 Accuracy: 41.65%, Top-5 Accuracy: 73.23%
# Epoch 30/70
# Train Loss: 1.9375, Train Accuracy: 46.36%
# Eval Loss: 2.2341, Eval Accuracy: 41.69%, Top-1 Accuracy: 41.69%, Top-5 Accuracy: 73.05%
# Epoch 31/70
# Train Loss: 1.9061, Train Accuracy: 47.23%
# Eval Loss: 2.1652, Eval Accuracy: 42.75%, Top-1 Accuracy: 42.75%, Top-5 Accuracy: 74.34%
# Epoch 32/70
# Train Loss: 1.8872, Train Accuracy: 47.68%
# Eval Loss: 2.2152, Eval Accuracy: 42.60%, Top-1 Accuracy: 42.60%, Top-5 Accuracy: 73.60%
# Epoch 33/70
# Train Loss: 1.8527, Train Accuracy: 48.64%
# Eval Loss: 2.1788, Eval Accuracy: 42.69%, Top-1 Accuracy: 42.69%, Top-5 Accuracy: 74.36%
# Epoch 34/70
# Train Loss: 1.8225, Train Accuracy: 49.09%
# Eval Loss: 2.2201, Eval Accuracy: 42.29%, Top-1 Accuracy: 42.29%, Top-5 Accuracy: 73.03%
# Epoch 35/70
# Train Loss: 1.8008, Train Accuracy: 50.04%
# Eval Loss: 2.2124, Eval Accuracy: 42.42%, Top-1 Accuracy: 42.42%, Top-5 Accuracy: 73.05%
# Epoch 36/70
# Train Loss: 1.7821, Train Accuracy: 50.25%
# Eval Loss: 2.1196, Eval Accuracy: 44.47%, Top-1 Accuracy: 44.47%, Top-5 Accuracy: 75.35%
# Epoch 37/70
# Train Loss: 1.7569, Train Accuracy: 50.63%
# Eval Loss: 2.1517, Eval Accuracy: 43.77%, Top-1 Accuracy: 43.77%, Top-5 Accuracy: 74.98%
# Epoch 38/70
# Train Loss: 1.7266, Train Accuracy: 51.60%
# Eval Loss: 2.1669, Eval Accuracy: 42.93%, Top-1 Accuracy: 42.93%, Top-5 Accuracy: 74.46%
# Epoch 39/70
# Train Loss: 1.7180, Train Accuracy: 51.86%
# Eval Loss: 2.1000, Eval Accuracy: 44.59%, Top-1 Accuracy: 44.59%, Top-5 Accuracy: 76.26%
# Epoch 40/70
# Train Loss: 1.6905, Train Accuracy: 52.61%
# Eval Loss: 2.1233, Eval Accuracy: 44.44%, Top-1 Accuracy: 44.44%, Top-5 Accuracy: 75.18%
# Epoch 41/70
# Train Loss: 1.6696, Train Accuracy: 52.71%
# Eval Loss: 2.1982, Eval Accuracy: 43.63%, Top-1 Accuracy: 43.63%, Top-5 Accuracy: 74.22%
# Epoch 42/70
# Train Loss: 1.6557, Train Accuracy: 53.20%
# Eval Loss: 2.0646, Eval Accuracy: 44.82%, Top-1 Accuracy: 44.82%, Top-5 Accuracy: 76.97%
# Epoch 43/70
# Train Loss: 1.6266, Train Accuracy: 53.81%
# Eval Loss: 2.1059, Eval Accuracy: 44.50%, Top-1 Accuracy: 44.50%, Top-5 Accuracy: 76.11%
# Epoch 44/70
# Train Loss: 1.6032, Train Accuracy: 54.31%
# Eval Loss: 2.1378, Eval Accuracy: 44.83%, Top-1 Accuracy: 44.83%, Top-5 Accuracy: 75.39%
# Epoch 45/70
# Train Loss: 1.5847, Train Accuracy: 55.21%
# Eval Loss: 2.0949, Eval Accuracy: 45.83%, Top-1 Accuracy: 45.83%, Top-5 Accuracy: 76.25%
# Epoch 46/70
# Train Loss: 1.5582, Train Accuracy: 55.75%
# Eval Loss: 2.1562, Eval Accuracy: 44.04%, Top-1 Accuracy: 44.04%, Top-5 Accuracy: 75.58%
# Epoch 47/70
# Train Loss: 1.5413, Train Accuracy: 55.86%
# Eval Loss: 2.0360, Eval Accuracy: 46.56%, Top-1 Accuracy: 46.56%, Top-5 Accuracy: 77.36%
# Epoch 48/70
# Train Loss: 1.5344, Train Accuracy: 56.11%
# Eval Loss: 2.0633, Eval Accuracy: 45.70%, Top-1 Accuracy: 45.70%, Top-5 Accuracy: 76.82%
# Epoch 49/70
# Train Loss: 1.5106, Train Accuracy: 56.49%
# Eval Loss: 2.1482, Eval Accuracy: 44.37%, Top-1 Accuracy: 44.37%, Top-5 Accuracy: 75.12%
# Epoch 50/70
# Train Loss: 1.5006, Train Accuracy: 57.17%
# Eval Loss: 2.0789, Eval Accuracy: 45.73%, Top-1 Accuracy: 45.73%, Top-5 Accuracy: 76.87%
# Epoch 51/70
# Train Loss: 1.4797, Train Accuracy: 57.24%
# Eval Loss: 2.0634, Eval Accuracy: 46.29%, Top-1 Accuracy: 46.29%, Top-5 Accuracy: 77.11%
# Epoch 52/70
# Train Loss: 1.4544, Train Accuracy: 58.15%
# Eval Loss: 2.0228, Eval Accuracy: 47.54%, Top-1 Accuracy: 47.54%, Top-5 Accuracy: 77.82%
# Epoch 53/70
# Train Loss: 1.4445, Train Accuracy: 58.18%
# Eval Loss: 2.1058, Eval Accuracy: 45.62%, Top-1 Accuracy: 45.62%, Top-5 Accuracy: 76.05%
# Epoch 54/70
# Train Loss: 1.4268, Train Accuracy: 58.82%
# Eval Loss: 2.0707, Eval Accuracy: 47.40%, Top-1 Accuracy: 47.40%, Top-5 Accuracy: 77.00%
# Epoch 55/70
# Train Loss: 1.4139, Train Accuracy: 58.82%
# Eval Loss: 2.0640, Eval Accuracy: 47.06%, Top-1 Accuracy: 47.06%, Top-5 Accuracy: 77.90%
# Epoch 56/70
# Train Loss: 1.3964, Train Accuracy: 59.28%
# Eval Loss: 2.0686, Eval Accuracy: 46.55%, Top-1 Accuracy: 46.55%, Top-5 Accuracy: 77.02%
# Epoch 57/70
# Train Loss: 1.3801, Train Accuracy: 59.91%
# Eval Loss: 1.9865, Eval Accuracy: 47.83%, Top-1 Accuracy: 47.83%, Top-5 Accuracy: 78.47%
# Epoch 58/70
# Train Loss: 1.3646, Train Accuracy: 60.30%
# Eval Loss: 1.9805, Eval Accuracy: 48.32%, Top-1 Accuracy: 48.32%, Top-5 Accuracy: 78.71%
# Epoch 59/70
# Train Loss: 1.3468, Train Accuracy: 60.70%
# Eval Loss: 2.0139, Eval Accuracy: 47.73%, Top-1 Accuracy: 47.73%, Top-5 Accuracy: 77.93%
# Epoch 60/70
# Train Loss: 1.3341, Train Accuracy: 61.05%
# Eval Loss: 2.0371, Eval Accuracy: 47.98%, Top-1 Accuracy: 47.98%, Top-5 Accuracy: 77.66%
# Epoch 61/70
# Train Loss: 1.3237, Train Accuracy: 61.46%
# Eval Loss: 2.1134, Eval Accuracy: 46.35%, Top-1 Accuracy: 46.35%, Top-5 Accuracy: 76.05%
# Epoch 62/70
# Train Loss: 1.3139, Train Accuracy: 61.46%
# Eval Loss: 1.9873, Eval Accuracy: 48.67%, Top-1 Accuracy: 48.67%, Top-5 Accuracy: 78.63%
# Epoch 63/70
# Train Loss: 1.2879, Train Accuracy: 62.23%
# Eval Loss: 2.0291, Eval Accuracy: 48.24%, Top-1 Accuracy: 48.24%, Top-5 Accuracy: 78.00%
# Epoch 64/70
# Train Loss: 1.2751, Train Accuracy: 62.31%
# Eval Loss: 2.0313, Eval Accuracy: 47.66%, Top-1 Accuracy: 47.66%, Top-5 Accuracy: 78.04%
# Epoch 65/70
# Train Loss: 1.2716, Train Accuracy: 62.41%
# Eval Loss: 1.9791, Eval Accuracy: 48.92%, Top-1 Accuracy: 48.92%, Top-5 Accuracy: 78.84%
# Epoch 66/70
# Train Loss: 1.2607, Train Accuracy: 63.03%
# Eval Loss: 2.0098, Eval Accuracy: 48.80%, Top-1 Accuracy: 48.80%, Top-5 Accuracy: 78.22%
# Epoch 67/70
# Train Loss: 1.2301, Train Accuracy: 63.53%
# Eval Loss: 2.1101, Eval Accuracy: 47.12%, Top-1 Accuracy: 47.12%, Top-5 Accuracy: 76.99%
# Epoch 68/70
# Train Loss: 1.2378, Train Accuracy: 63.29%
# Eval Loss: 2.0571, Eval Accuracy: 48.27%, Top-1 Accuracy: 48.27%, Top-5 Accuracy: 77.98%
# Epoch 69/70
# Train Loss: 1.2168, Train Accuracy: 64.19%
# Eval Loss: 2.0851, Eval Accuracy: 47.60%, Top-1 Accuracy: 47.60%, Top-5 Accuracy: 77.91%
# Epoch 70/70
# Train Loss: 1.2026, Train Accuracy: 64.23%
# Eval Loss: 1.9733, Eval Accuracy: 49.38%, Top-1 Accuracy: 49.38%, Top-5 Accuracy: 78.89%

# %%
# custom mobilenetv2 model config wtih additional drop
class CustomMobileNetV2(nn.Module):
    def __init__(self, num_classes=100, dropout_rate=0.5):
        super(CustomMobileNetV2, self).__init__()
        self.mobilenet_v2 = models.mobilenet_v2(pretrained=False)
        self.mobilenet_v2.classifier = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.mobilenet_v2.last_channel, num_classes)
        )
    def forward(self, x):
        return self.mobilenet_v2(x)
config = {
    'dataloader' : cf100_w_aug,
    'model': CustomMobileNetV2(),
    'epochs': 70,
    'optimizer': 'SGD',
    'learning_rate': 0.01,
    'momentum': 0.9,
    'weight_decay': 5e-4,
    'loss': nn.CrossEntropyLoss(),
    'log_dir': os.path.join(BASE_LOGS_PATH, time.strftime('%Y%m%d_%H%M%S') + '_logs'),
    'device' : device,
    'run_time' : None
}
model = config['model']
model.to(config['device'])
criterion = config['loss']
optimizer = torch.optim.SGD(model.parameters(),
                            lr=config['learning_rate'],
                            momentum=config['momentum'],
                            weight_decay=config['weight_decay'])

if not os.path.exists(config['log_dir']):
    os.makedirs(config['log_dir'])
    print(f"Directory '{config['log_dir']}' created")

metrics_path = os.path.join(config['log_dir'], 'training_metrics.csv')
with open(metrics_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Epoch', 'Train Loss', 'Train Accuracy', 'Eval Loss', 'Eval Accuracy', 'Top-1 Accuracy', 'Top-5 Accuracy', 'Epoch Time (seconds)'])
    for epoch in range(config['epochs']):
        start_time = timeit.default_timer()
        train_losses = []
        train_accuracies = []
        model.train()
        for images, labels in config['dataloader'].train_data_loader:
            images, labels = images.to(config['device']), labels.to(config['device'])
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())
            _, predicted = torch.max(outputs, 1)
            accuracy = (predicted == labels).float().mean().item()
            train_accuracies.append(accuracy)

        eval_losses = []
        eval_accuracies = []
        top1_accuracies = []
        top5_accuracies = []
        model.eval()
        with torch.no_grad():
            for images, labels in config['dataloader'].eval_data_loader:
                images, labels = images.to(config['device']), labels.to(config['device'])
                outputs = model(images)
                loss = criterion(outputs, labels)
                eval_losses.append(loss.item())
                _, predicted = torch.max(outputs, 1)
                top1_accuracy = (predicted == labels).float().mean().item()
                top1_accuracies.append(top1_accuracy)
                _, top5_preds = outputs.topk(5, dim=1)
                top5_correct = top5_preds.eq(labels.view(-1, 1).expand_as(top5_preds))
                top5_accuracy = top5_correct.float().sum(1).ge(1).float().mean().item()
                top5_accuracies.append(top5_accuracy)
                eval_accuracies.append(top1_accuracy)

        end_time = timeit.default_timer()
        epoch_duration = end_time - start_time
        writer.writerow([
            epoch + 1,
            np.mean(train_losses),
            np.mean(train_accuracies) * 100,
            np.mean(eval_losses),
            np.mean(eval_accuracies) * 100,
            np.mean(top1_accuracies) * 100,
            np.mean(top5_accuracies) * 100,
            epoch_duration
        ])
        print(f"Epoch {epoch+1}/{config['epochs']}")
        print(f"Train Loss: {np.mean(train_losses):.4f}, Train Accuracy: {np.mean(train_accuracies) * 100:.2f}%")
        print(f"Eval Loss: {np.mean(eval_losses):.4f}, Eval Accuracy: {np.mean(eval_accuracies) * 100:.2f}%, Top-1 Accuracy: {np.mean(top1_accuracies) * 100:.2f}%, Top-5 Accuracy: {np.mean(top5_accuracies) * 100:.2f}%")

torch.save(model.state_dict(), os.path.join(config['log_dir'], 'model_state_dict.pth'))
torch.save(model, os.path.join(config['log_dir'], 'complete_model.pth'))
# Out:
# Directory 'drive/MyDrive/DS5220: Final Project/logs/mobilenet_v2/20240426_201747_logs' created
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1/70
# Train Loss: 4.3228, Train Accuracy: 4.95%
# Eval Loss: 3.9498, Eval Accuracy: 9.09%, Top-1 Accuracy: 9.09%, Top-5 Accuracy: 28.61%
# Epoch 2/70
# Train Loss: 3.9252, Train Accuracy: 9.47%
# Eval Loss: 3.6308, Eval Accuracy: 14.43%, Top-1 Accuracy: 14.43%, Top-5 Accuracy: 38.04%
# Epoch 3/70
# Train Loss: 3.6973, Train Accuracy: 12.82%
# Eval Loss: 3.4587, Eval Accuracy: 17.11%, Top-1 Accuracy: 17.11%, Top-5 Accuracy: 42.63%
# Epoch 4/70
# Train Loss: 3.5399, Train Accuracy: 15.41%
# Eval Loss: 3.3352, Eval Accuracy: 18.56%, Top-1 Accuracy: 18.56%, Top-5 Accuracy: 46.31%
# Epoch 5/70
# Train Loss: 3.4200, Train Accuracy: 17.46%
# Eval Loss: 3.2451, Eval Accuracy: 21.29%, Top-1 Accuracy: 21.29%, Top-5 Accuracy: 49.03%
# Epoch 6/70
# Train Loss: 3.3220, Train Accuracy: 19.00%
# Eval Loss: 3.1867, Eval Accuracy: 21.75%, Top-1 Accuracy: 21.75%, Top-5 Accuracy: 50.09%
# Epoch 7/70
# Train Loss: 3.2362, Train Accuracy: 20.82%
# Eval Loss: 3.1056, Eval Accuracy: 23.55%, Top-1 Accuracy: 23.55%, Top-5 Accuracy: 52.54%
# Epoch 8/70
# Train Loss: 3.1675, Train Accuracy: 21.98%
# Eval Loss: 3.0251, Eval Accuracy: 25.27%, Top-1 Accuracy: 25.27%, Top-5 Accuracy: 54.53%
# Epoch 9/70
# Train Loss: 3.0913, Train Accuracy: 23.28%
# Eval Loss: 2.9763, Eval Accuracy: 26.28%, Top-1 Accuracy: 26.28%, Top-5 Accuracy: 55.53%
# Epoch 10/70
# Train Loss: 3.0253, Train Accuracy: 24.51%
# Eval Loss: 2.9559, Eval Accuracy: 26.11%, Top-1 Accuracy: 26.11%, Top-5 Accuracy: 56.04%
# Epoch 11/70
# Train Loss: 2.9717, Train Accuracy: 25.50%
# Eval Loss: 2.9098, Eval Accuracy: 27.36%, Top-1 Accuracy: 27.36%, Top-5 Accuracy: 57.18%
# Epoch 12/70
# Train Loss: 2.9207, Train Accuracy: 26.19%
# Eval Loss: 2.8330, Eval Accuracy: 29.21%, Top-1 Accuracy: 29.21%, Top-5 Accuracy: 59.18%
# Epoch 13/70
# Train Loss: 2.8626, Train Accuracy: 27.46%
# Eval Loss: 2.8207, Eval Accuracy: 28.97%, Top-1 Accuracy: 28.97%, Top-5 Accuracy: 59.03%
# Epoch 14/70
# Train Loss: 2.8140, Train Accuracy: 28.51%
# Eval Loss: 2.7962, Eval Accuracy: 29.92%, Top-1 Accuracy: 29.92%, Top-5 Accuracy: 59.94%
# Epoch 15/70
# Train Loss: 2.7619, Train Accuracy: 29.74%
# Eval Loss: 2.7418, Eval Accuracy: 31.02%, Top-1 Accuracy: 31.02%, Top-5 Accuracy: 61.04%
# Epoch 16/70
# Train Loss: 2.7211, Train Accuracy: 30.30%
# Eval Loss: 2.7121, Eval Accuracy: 30.89%, Top-1 Accuracy: 30.89%, Top-5 Accuracy: 62.57%
# Epoch 17/70
# Train Loss: 2.6699, Train Accuracy: 31.35%
# Eval Loss: 2.7241, Eval Accuracy: 31.02%, Top-1 Accuracy: 31.02%, Top-5 Accuracy: 61.55%
# Epoch 18/70
# Train Loss: 2.6211, Train Accuracy: 32.15%
# Eval Loss: 2.6301, Eval Accuracy: 33.31%, Top-1 Accuracy: 33.31%, Top-5 Accuracy: 63.67%
# Epoch 19/70
# Train Loss: 2.5740, Train Accuracy: 33.43%
# Eval Loss: 2.5748, Eval Accuracy: 33.74%, Top-1 Accuracy: 33.74%, Top-5 Accuracy: 65.36%
# Epoch 20/70
# Train Loss: 2.5458, Train Accuracy: 33.84%
# Eval Loss: 2.5614, Eval Accuracy: 34.51%, Top-1 Accuracy: 34.51%, Top-5 Accuracy: 65.74%
# Epoch 21/70
# Train Loss: 2.4939, Train Accuracy: 34.80%
# Eval Loss: 2.5790, Eval Accuracy: 32.97%, Top-1 Accuracy: 32.97%, Top-5 Accuracy: 65.32%
# Epoch 22/70
# Train Loss: 2.4594, Train Accuracy: 35.73%
# Eval Loss: 2.4932, Eval Accuracy: 35.52%, Top-1 Accuracy: 35.52%, Top-5 Accuracy: 67.18%
# Epoch 23/70
# Train Loss: 2.4104, Train Accuracy: 36.81%
# Eval Loss: 2.4546, Eval Accuracy: 37.07%, Top-1 Accuracy: 37.07%, Top-5 Accuracy: 67.70%
# Epoch 24/70
# Train Loss: 2.3678, Train Accuracy: 37.36%
# Eval Loss: 2.3773, Eval Accuracy: 38.34%, Top-1 Accuracy: 38.34%, Top-5 Accuracy: 69.54%
# Epoch 25/70
# Train Loss: 2.3331, Train Accuracy: 38.44%
# Eval Loss: 2.5050, Eval Accuracy: 35.41%, Top-1 Accuracy: 35.41%, Top-5 Accuracy: 67.30%
# Epoch 26/70
# Train Loss: 2.2914, Train Accuracy: 38.95%
# Eval Loss: 2.3734, Eval Accuracy: 38.04%, Top-1 Accuracy: 38.04%, Top-5 Accuracy: 69.45%
# Epoch 27/70
# Train Loss: 2.2454, Train Accuracy: 39.97%
# Eval Loss: 2.3431, Eval Accuracy: 38.90%, Top-1 Accuracy: 38.90%, Top-5 Accuracy: 70.81%
# Epoch 28/70
# Train Loss: 2.2199, Train Accuracy: 40.72%
# Eval Loss: 2.3496, Eval Accuracy: 39.17%, Top-1 Accuracy: 39.17%, Top-5 Accuracy: 70.02%
# Epoch 29/70
# Train Loss: 2.1748, Train Accuracy: 41.71%
# Eval Loss: 2.3510, Eval Accuracy: 39.35%, Top-1 Accuracy: 39.35%, Top-5 Accuracy: 70.44%
# Epoch 30/70
# Train Loss: 2.1505, Train Accuracy: 42.19%
# Eval Loss: 2.3165, Eval Accuracy: 39.84%, Top-1 Accuracy: 39.84%, Top-5 Accuracy: 70.89%
# Epoch 31/70
# Train Loss: 2.1173, Train Accuracy: 42.95%
# Eval Loss: 2.2414, Eval Accuracy: 41.47%, Top-1 Accuracy: 41.47%, Top-5 Accuracy: 72.43%
# Epoch 32/70
# Train Loss: 2.0716, Train Accuracy: 43.90%
# Eval Loss: 2.2683, Eval Accuracy: 40.68%, Top-1 Accuracy: 40.68%, Top-5 Accuracy: 71.72%
# Epoch 33/70
# Train Loss: 2.0567, Train Accuracy: 44.10%
# Eval Loss: 2.2173, Eval Accuracy: 41.97%, Top-1 Accuracy: 41.97%, Top-5 Accuracy: 72.98%
# Epoch 34/70
# Train Loss: 2.0339, Train Accuracy: 44.77%
# Eval Loss: 2.2037, Eval Accuracy: 42.45%, Top-1 Accuracy: 42.45%, Top-5 Accuracy: 73.63%
# Epoch 35/70
# Train Loss: 1.9987, Train Accuracy: 45.75%
# Eval Loss: 2.1851, Eval Accuracy: 42.47%, Top-1 Accuracy: 42.47%, Top-5 Accuracy: 73.60%
# Epoch 36/70
# Train Loss: 1.9723, Train Accuracy: 46.13%
# Eval Loss: 2.2042, Eval Accuracy: 42.36%, Top-1 Accuracy: 42.36%, Top-5 Accuracy: 73.13%
# Epoch 37/70
# Train Loss: 1.9460, Train Accuracy: 46.69%
# Eval Loss: 2.2274, Eval Accuracy: 42.16%, Top-1 Accuracy: 42.16%, Top-5 Accuracy: 73.31%
# Epoch 38/70
# Train Loss: 1.9159, Train Accuracy: 47.44%
# Eval Loss: 2.1600, Eval Accuracy: 43.50%, Top-1 Accuracy: 43.50%, Top-5 Accuracy: 73.79%
# Epoch 39/70
# Train Loss: 1.8843, Train Accuracy: 48.40%
# Eval Loss: 2.1371, Eval Accuracy: 43.24%, Top-1 Accuracy: 43.24%, Top-5 Accuracy: 75.02%
# Epoch 40/70
# Train Loss: 1.8711, Train Accuracy: 48.37%
# Eval Loss: 2.1928, Eval Accuracy: 42.50%, Top-1 Accuracy: 42.50%, Top-5 Accuracy: 73.59%
# Epoch 41/70
# Train Loss: 1.8359, Train Accuracy: 49.18%
# Eval Loss: 2.0971, Eval Accuracy: 44.47%, Top-1 Accuracy: 44.47%, Top-5 Accuracy: 75.41%
# Epoch 42/70
# Train Loss: 1.8296, Train Accuracy: 49.36%
# Eval Loss: 2.0824, Eval Accuracy: 44.74%, Top-1 Accuracy: 44.74%, Top-5 Accuracy: 75.79%
# Epoch 43/70
# Train Loss: 1.8007, Train Accuracy: 50.20%
# Eval Loss: 2.0867, Eval Accuracy: 44.33%, Top-1 Accuracy: 44.33%, Top-5 Accuracy: 75.88%
# Epoch 44/70
# Train Loss: 1.7788, Train Accuracy: 50.77%
# Eval Loss: 2.1095, Eval Accuracy: 44.69%, Top-1 Accuracy: 44.69%, Top-5 Accuracy: 75.19%
# Epoch 45/70
# Train Loss: 1.7594, Train Accuracy: 51.07%
# Eval Loss: 2.1320, Eval Accuracy: 44.17%, Top-1 Accuracy: 44.17%, Top-5 Accuracy: 75.01%
# Epoch 46/70
# Train Loss: 1.7418, Train Accuracy: 51.45%
# Eval Loss: 2.1075, Eval Accuracy: 44.62%, Top-1 Accuracy: 44.62%, Top-5 Accuracy: 75.44%
# Epoch 47/70
# Train Loss: 1.7268, Train Accuracy: 52.07%
# Eval Loss: 2.0750, Eval Accuracy: 45.69%, Top-1 Accuracy: 45.69%, Top-5 Accuracy: 75.87%
# Epoch 48/70
# Train Loss: 1.6967, Train Accuracy: 52.51%
# Eval Loss: 2.0944, Eval Accuracy: 45.31%, Top-1 Accuracy: 45.31%, Top-5 Accuracy: 75.80%
# Epoch 49/70
# Train Loss: 1.6820, Train Accuracy: 53.04%
# Eval Loss: 2.1406, Eval Accuracy: 44.06%, Top-1 Accuracy: 44.06%, Top-5 Accuracy: 74.74%
# Epoch 50/70
# Train Loss: 1.6589, Train Accuracy: 53.63%
# Eval Loss: 2.1206, Eval Accuracy: 44.98%, Top-1 Accuracy: 44.98%, Top-5 Accuracy: 75.70%
# Epoch 51/70
# Train Loss: 1.6554, Train Accuracy: 53.40%
# Eval Loss: 2.0617, Eval Accuracy: 45.94%, Top-1 Accuracy: 45.94%, Top-5 Accuracy: 76.39%
# Epoch 52/70
# Train Loss: 1.6255, Train Accuracy: 54.26%
# Eval Loss: 2.0824, Eval Accuracy: 46.41%, Top-1 Accuracy: 46.41%, Top-5 Accuracy: 76.12%
# Epoch 53/70
# Train Loss: 1.6128, Train Accuracy: 54.59%
# Eval Loss: 2.1001, Eval Accuracy: 46.04%, Top-1 Accuracy: 46.04%, Top-5 Accuracy: 75.94%
# Epoch 54/70
# Train Loss: 1.5862, Train Accuracy: 55.07%
# Eval Loss: 2.0377, Eval Accuracy: 46.41%, Top-1 Accuracy: 46.41%, Top-5 Accuracy: 77.29%
# Epoch 55/70
# Train Loss: 1.5848, Train Accuracy: 55.08%
# Eval Loss: 2.0730, Eval Accuracy: 46.41%, Top-1 Accuracy: 46.41%, Top-5 Accuracy: 76.29%
# Epoch 56/70
# Train Loss: 1.5562, Train Accuracy: 55.77%
# Eval Loss: 2.0105, Eval Accuracy: 47.77%, Top-1 Accuracy: 47.77%, Top-5 Accuracy: 77.69%
# Epoch 57/70
# Train Loss: 1.5442, Train Accuracy: 56.11%
# Eval Loss: 2.0288, Eval Accuracy: 47.31%, Top-1 Accuracy: 47.31%, Top-5 Accuracy: 77.23%
# Epoch 58/70
# Train Loss: 1.5337, Train Accuracy: 56.54%
# Eval Loss: 2.0327, Eval Accuracy: 47.73%, Top-1 Accuracy: 47.73%, Top-5 Accuracy: 77.22%
# Epoch 59/70
# Train Loss: 1.5142, Train Accuracy: 56.75%
# Eval Loss: 2.0153, Eval Accuracy: 47.47%, Top-1 Accuracy: 47.47%, Top-5 Accuracy: 77.44%
# Epoch 60/70
# Train Loss: 1.4973, Train Accuracy: 57.37%
# Eval Loss: 2.0146, Eval Accuracy: 48.02%, Top-1 Accuracy: 48.02%, Top-5 Accuracy: 77.68%
# Epoch 61/70
# Train Loss: 1.4863, Train Accuracy: 57.48%
# Eval Loss: 2.0644, Eval Accuracy: 46.67%, Top-1 Accuracy: 46.67%, Top-5 Accuracy: 77.22%
# Epoch 62/70
# Train Loss: 1.4680, Train Accuracy: 57.96%
# Eval Loss: 2.1139, Eval Accuracy: 45.88%, Top-1 Accuracy: 45.88%, Top-5 Accuracy: 75.67%
# Epoch 63/70
# Train Loss: 1.4576, Train Accuracy: 58.34%
# Eval Loss: 2.0465, Eval Accuracy: 47.12%, Top-1 Accuracy: 47.12%, Top-5 Accuracy: 77.47%
# Epoch 64/70
# Train Loss: 1.4454, Train Accuracy: 58.55%
# Eval Loss: 2.1458, Eval Accuracy: 45.53%, Top-1 Accuracy: 45.53%, Top-5 Accuracy: 75.89%
# Epoch 65/70
# Train Loss: 1.4398, Train Accuracy: 58.67%
# Eval Loss: 1.9735, Eval Accuracy: 49.00%, Top-1 Accuracy: 49.00%, Top-5 Accuracy: 78.47%
# Epoch 66/70
# Train Loss: 1.4237, Train Accuracy: 59.35%
# Eval Loss: 2.0048, Eval Accuracy: 47.74%, Top-1 Accuracy: 47.74%, Top-5 Accuracy: 78.62%
# Epoch 67/70
# Train Loss: 1.4021, Train Accuracy: 59.62%
# Eval Loss: 1.9990, Eval Accuracy: 48.71%, Top-1 Accuracy: 48.71%, Top-5 Accuracy: 78.14%
# Epoch 68/70
# Train Loss: 1.3916, Train Accuracy: 60.05%
# Eval Loss: 2.0286, Eval Accuracy: 48.26%, Top-1 Accuracy: 48.26%, Top-5 Accuracy: 77.64%
# Epoch 69/70
# Train Loss: 1.3968, Train Accuracy: 59.85%
# Eval Loss: 2.0299, Eval Accuracy: 48.71%, Top-1 Accuracy: 48.71%, Top-5 Accuracy: 77.41%
# Epoch 70/70
# Train Loss: 1.3721, Train Accuracy: 60.34%
# Eval Loss: 2.0459, Eval Accuracy: 47.45%, Top-1 Accuracy: 47.45%, Top-5 Accuracy: 77.19%
