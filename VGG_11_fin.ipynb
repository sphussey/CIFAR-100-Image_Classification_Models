# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import os
from datetime import datetime
import pytz
from pathlib import Path
import sklearn as sk
import tensorflow as tf
import torch
import torch.nn as nn
from torchvision.io import read_image
import time
import timeit
import random
import torchvision.models as models
from torchvision.datasets import CIFAR100
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as transforms
import sklearn.metrics
import csv
import timeit

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls 'drive/MyDrive/DS5220: Final Project/logs/VGG_11'
# Out:
# 20240425_192641_logs/

# %%
BASE_LOGS_PATH = 'drive/MyDrive/DS5220: Final Project/logs/VGG_11'

# %%
# https://pytorch.org/docs/stable/notes/mps.html

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
## Data cleaning & preprocessing

CIFAR100_ROOT_PATH='drive/MyDrive/DS5220: Final Project'

class Cifar100():
    def __init__(self,
                 calculate_mean_and_std = False):

        if calculate_mean_and_std:
            self.mean, self.std = self.calculate_mean_and_std()
        else:
            self.mean, self.std = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

        self.BATCH_SIZE = 128
        self.transform = transforms.Compose(
            [transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)])

        self.train_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                download=True,
                                train=True,
                                transform=self.transform)

        self.eval_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                train=False,
                                transform=self.transform)

        self.train_data_loader = DataLoader(dataset=self.train_dataset,
                               num_workers=0,
                               batch_size=self.BATCH_SIZE,
                               shuffle=True)

        self.eval_data_loader = DataLoader(dataset=self.eval_dataset,
                              num_workers=0,
                              batch_size=self.BATCH_SIZE,
                              shuffle=False)

    def calculate_mean_and_std(self):

        train_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                download=True,
                                train=True)
        x = np.concatenate([np.asarray(train_dataset[i][0]) for i in range(len(train_dataset))])
        _mean = np.mean(x, axis=(0, 1))/255
        _std = np.std(x, axis=(0, 1))/255
        _mean = _mean.tolist()
        _std = _std.tolist()

        return _mean, _std



# data augmentation
class Cifar100WithAugmentation():
    def __init__(self, calculate_mean_and_std=False):
        CIFAR100_ROOT_PATH = 'drive/MyDrive/DS5220: Final Project'
        if calculate_mean_and_std:
            self.mean, self.std = self.calculate_mean_and_std()
        else:
            self.mean, self.std = (0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)

        self.BATCH_SIZE = 128

        self.train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)
        ])

        self.eval_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)
        ])
        self.train_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                               download=True,
                                               train=True,
                                               transform=self.train_transform)

        self.eval_dataset = CIFAR100(root=CIFAR100_ROOT_PATH,
                                              train=False,
                                              transform=self.eval_transform)

        self.train_data_loader = DataLoader(dataset=self.train_dataset,
                                            num_workers=4,
                                            batch_size=self.BATCH_SIZE,
                                            shuffle=True)

        self.eval_data_loader = DataLoader(dataset=self.eval_dataset,
                                           num_workers=4,
                                           batch_size=self.BATCH_SIZE,
                                           shuffle=False)

    def calculate_mean_and_std(self):
        train_dataset = CIFAR100(root='drive/MyDrive/DS5220: Final Project',
                                          download=True,
                                          train=True)
        x = np.concatenate([np.asarray(train_dataset[i][0]) for i in range(len(train_dataset))])
        mean = np.mean(x, axis=(0, 1)) / 255
        std = np.std(x, axis=(0, 1)) / 255
        return mean.tolist(), std.tolist()


cf100 = Cifar100(calculate_mean_and_std=True)
cf100_w_aug = Cifar100WithAugmentation(calculate_mean_and_std=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# model config for VGG11
config = {
    'dataloader' : cf100_w_aug,
    'model': models.vgg11(),
    'epochs': 40,
    'optimizer': 'SGD',
    'learning_rate': 0.01,
    'momentum': 0.9,
    'weight_decay': 5e-4,
    'loss': nn.CrossEntropyLoss(),
    'log_dir': os.path.join(BASE_LOGS_PATH, time.strftime('%Y%m%d_%H%M%S') + '_logs'),
    'device' : device,
    'run_time' : None
}

model = config['model']
model.to(device)
EPOCHS = config['epochs']
criterion = config['loss']
optimizer = torch.optim.SGD(model.parameters(),
                            lr=config['learning_rate'],
                            momentum=config['momentum'],
                            weight_decay=config['weight_decay'])

if not os.path.exists(config['log_dir']):
    os.makedirs(config['log_dir'])
    print(f"Directory '{config['log_dir']}' created")
else:
    print(f"Directory '{config['log_dir']}' already exists")

metrics_path = os.path.join(config['log_dir'], 'training_metrics.csv')
with open(metrics_path, mode='w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(['Epoch', 'Train Loss', 'Train Accuracy', 'Eval Loss', 'Eval Accuracy', 'Top-1 Accuracy', 'Top-5 Accuracy', 'Epoch Time (seconds)'])
    training_start_time = timeit.default_timer()
    for epoch in range(config['epochs']):
        start_time = timeit.default_timer()
        train_losses = []
        train_accuracies = []
        model.train()
        for images, labels in config['dataloader'].train_data_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())
            _, predicted = torch.max(outputs, 1)
            accuracy = (predicted == labels).float().mean().item()
            train_accuracies.append(accuracy)

        eval_losses = []
        eval_accuracies = []
        top1_accuracies = []
        top5_accuracies = []
        model.eval()
        with torch.no_grad():
            for images, labels in config['dataloader'].eval_data_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                eval_losses.append(loss.item())

                #  top-1 accuracy
                _, predicted = torch.max(outputs, 1)
                top1_accuracy = (predicted == labels).float().mean().item()
                top1_accuracies.append(top1_accuracy)

                #  top-5 accuracy
                _, top5_preds = outputs.topk(5, dim=1)
                top5_correct = top5_preds.eq(labels.view(-1, 1).expand_as(top5_preds))
                top5_accuracy = top5_correct.float().sum(1).ge(1).float().mean().item()
                top5_accuracies.append(top5_accuracy)

                eval_accuracies.append(top1_accuracy)

        end_time = timeit.default_timer()
        epoch_duration = end_time - start_time
        writer.writerow([
            epoch + 1,
            np.mean(train_losses),
            np.mean(train_accuracies) * 100,
            np.mean(eval_losses),
            np.mean(eval_accuracies) * 100,
            np.mean(top1_accuracies) * 100,
            np.mean(top5_accuracies) * 100,
            epoch_duration
        ])
        print(f"Epoch {epoch+1}/{config['epochs']}")
        print(f"Train Loss: {np.mean(train_losses):.4f}, Train Accuracy: {np.mean(train_accuracies) * 100:.2f}%")
        print(f"Eval Loss: {np.mean(eval_losses):.4f}, Eval Accuracy: {np.mean(eval_accuracies) * 100:.2f}%, Top-1 Accuracy: {np.mean(top1_accuracies) * 100:.2f}%, Top-5 Accuracy: {np.mean(top5_accuracies) * 100:.2f}%")
    training_end_time = timeit.default_timer()
    training_duration = training_end_time - training_start_time
    config['run_time'] = training_duration
config_path = os.path.join(config['log_dir'], 'config.txt')
with open(config_path, 'w') as f:
    for key, value in config.items():
        f.write(f'{key}: {value}\n')


torch.save(model.state_dict(), os.path.join(config['log_dir'], 'model_state_dict.pth'))
torch.save(model, os.path.join(config['log_dir'], 'complete_model.pth'))
# Out:
# Directory 'drive/MyDrive/DS5220: Final Project/logs/VGG_11/20240425_213841_logs' created
# Epoch 1/40
# Train Loss: 4.6586, Train Accuracy: 2.36%
# Eval Loss: 4.1865, Eval Accuracy: 5.06%, Top-1 Accuracy: 5.06%, Top-5 Accuracy: 20.02%
# Epoch 2/40
# Train Loss: 4.0202, Train Accuracy: 6.82%
# Eval Loss: 3.7570, Eval Accuracy: 10.96%, Top-1 Accuracy: 10.96%, Top-5 Accuracy: 32.18%
# Epoch 3/40
# Train Loss: 3.7036, Train Accuracy: 11.25%
# Eval Loss: 3.4470, Eval Accuracy: 15.78%, Top-1 Accuracy: 15.78%, Top-5 Accuracy: 43.41%
# Epoch 4/40
# Train Loss: 3.4066, Train Accuracy: 16.49%
# Eval Loss: 3.2012, Eval Accuracy: 19.92%, Top-1 Accuracy: 19.92%, Top-5 Accuracy: 50.00%
# Epoch 5/40
# Train Loss: 3.1489, Train Accuracy: 21.10%
# Eval Loss: 2.9365, Eval Accuracy: 24.99%, Top-1 Accuracy: 24.99%, Top-5 Accuracy: 57.03%
# Epoch 6/40
# Train Loss: 2.9292, Train Accuracy: 25.42%
# Eval Loss: 2.6702, Eval Accuracy: 31.36%, Top-1 Accuracy: 31.36%, Top-5 Accuracy: 63.88%
# Epoch 7/40
# Train Loss: 2.7432, Train Accuracy: 28.91%
# Eval Loss: 2.6046, Eval Accuracy: 32.90%, Top-1 Accuracy: 32.90%, Top-5 Accuracy: 64.62%
# Epoch 8/40
# Train Loss: 2.5889, Train Accuracy: 32.24%
# Eval Loss: 2.4689, Eval Accuracy: 34.99%, Top-1 Accuracy: 34.99%, Top-5 Accuracy: 68.26%
# Epoch 9/40
# Train Loss: 2.4312, Train Accuracy: 35.67%
# Eval Loss: 2.3200, Eval Accuracy: 38.58%, Top-1 Accuracy: 38.58%, Top-5 Accuracy: 71.13%
# Epoch 10/40
# Train Loss: 2.3159, Train Accuracy: 38.63%
# Eval Loss: 2.2262, Eval Accuracy: 40.53%, Top-1 Accuracy: 40.53%, Top-5 Accuracy: 73.24%
# Epoch 11/40
# Train Loss: 2.2091, Train Accuracy: 40.80%
# Eval Loss: 2.1628, Eval Accuracy: 42.46%, Top-1 Accuracy: 42.46%, Top-5 Accuracy: 74.30%
# Epoch 12/40
# Train Loss: 2.1025, Train Accuracy: 43.54%
# Eval Loss: 2.0651, Eval Accuracy: 45.43%, Top-1 Accuracy: 45.43%, Top-5 Accuracy: 75.90%
# Epoch 13/40
# Train Loss: 2.0225, Train Accuracy: 45.34%
# Eval Loss: 2.0443, Eval Accuracy: 45.56%, Top-1 Accuracy: 45.56%, Top-5 Accuracy: 76.63%
# Epoch 14/40
# Train Loss: 1.9151, Train Accuracy: 47.67%
# Eval Loss: 1.9572, Eval Accuracy: 47.63%, Top-1 Accuracy: 47.63%, Top-5 Accuracy: 78.28%
# Epoch 15/40
# Train Loss: 1.8404, Train Accuracy: 49.68%
# Eval Loss: 1.9493, Eval Accuracy: 48.10%, Top-1 Accuracy: 48.10%, Top-5 Accuracy: 78.12%
# Epoch 16/40
# Train Loss: 1.7879, Train Accuracy: 50.70%
# Eval Loss: 1.9128, Eval Accuracy: 49.35%, Top-1 Accuracy: 49.35%, Top-5 Accuracy: 79.24%
# Epoch 17/40
# Train Loss: 1.7162, Train Accuracy: 52.67%
# Eval Loss: 1.8520, Eval Accuracy: 50.45%, Top-1 Accuracy: 50.45%, Top-5 Accuracy: 79.72%
# Epoch 18/40
# Train Loss: 1.6581, Train Accuracy: 53.98%
# Eval Loss: 1.8419, Eval Accuracy: 50.94%, Top-1 Accuracy: 50.94%, Top-5 Accuracy: 80.03%
# Epoch 19/40
# Train Loss: 1.5857, Train Accuracy: 55.45%
# Eval Loss: 1.8633, Eval Accuracy: 51.02%, Top-1 Accuracy: 51.02%, Top-5 Accuracy: 79.88%
# Epoch 20/40
# Train Loss: 1.5334, Train Accuracy: 56.89%
# Eval Loss: 1.8092, Eval Accuracy: 52.45%, Top-1 Accuracy: 52.45%, Top-5 Accuracy: 80.61%
# Epoch 21/40
# Train Loss: 1.4715, Train Accuracy: 58.81%
# Eval Loss: 1.7493, Eval Accuracy: 53.15%, Top-1 Accuracy: 53.15%, Top-5 Accuracy: 82.12%
# Epoch 22/40
# Train Loss: 1.4155, Train Accuracy: 59.85%
# Eval Loss: 1.7768, Eval Accuracy: 53.41%, Top-1 Accuracy: 53.41%, Top-5 Accuracy: 81.59%
# Epoch 23/40
# Train Loss: 1.3812, Train Accuracy: 60.76%
# Eval Loss: 1.7919, Eval Accuracy: 53.15%, Top-1 Accuracy: 53.15%, Top-5 Accuracy: 81.15%
# Epoch 24/40
# Train Loss: 1.3276, Train Accuracy: 62.20%
# Eval Loss: 1.7646, Eval Accuracy: 53.59%, Top-1 Accuracy: 53.59%, Top-5 Accuracy: 81.71%
# Epoch 25/40
# Train Loss: 1.2796, Train Accuracy: 63.33%
# Eval Loss: 1.7697, Eval Accuracy: 54.05%, Top-1 Accuracy: 54.05%, Top-5 Accuracy: 81.91%
# Epoch 26/40
# Train Loss: 1.2451, Train Accuracy: 64.18%
# Eval Loss: 1.7137, Eval Accuracy: 55.43%, Top-1 Accuracy: 55.43%, Top-5 Accuracy: 82.34%
# Epoch 27/40
# Train Loss: 1.1985, Train Accuracy: 65.48%
# Eval Loss: 1.6639, Eval Accuracy: 56.86%, Top-1 Accuracy: 56.86%, Top-5 Accuracy: 83.54%
# Epoch 28/40
# Train Loss: 1.1534, Train Accuracy: 66.61%
# Eval Loss: 1.7306, Eval Accuracy: 56.59%, Top-1 Accuracy: 56.59%, Top-5 Accuracy: 82.86%
# Epoch 29/40
# Train Loss: 1.1043, Train Accuracy: 67.90%
# Eval Loss: 1.7315, Eval Accuracy: 56.52%, Top-1 Accuracy: 56.52%, Top-5 Accuracy: 83.01%
# Epoch 30/40
# Train Loss: 1.0931, Train Accuracy: 68.21%
# Eval Loss: 1.7452, Eval Accuracy: 55.84%, Top-1 Accuracy: 55.84%, Top-5 Accuracy: 82.73%
# Epoch 31/40
# Train Loss: 1.0460, Train Accuracy: 69.45%
# Eval Loss: 1.7120, Eval Accuracy: 56.82%, Top-1 Accuracy: 56.82%, Top-5 Accuracy: 83.55%
# Epoch 32/40
# Train Loss: 1.0218, Train Accuracy: 70.10%
# Eval Loss: 1.7699, Eval Accuracy: 56.33%, Top-1 Accuracy: 56.33%, Top-5 Accuracy: 82.49%
# Epoch 33/40
# Train Loss: 0.9906, Train Accuracy: 70.83%
# Eval Loss: 1.7363, Eval Accuracy: 57.07%, Top-1 Accuracy: 57.07%, Top-5 Accuracy: 83.07%
# Epoch 34/40
# Train Loss: 0.9489, Train Accuracy: 72.05%
# Eval Loss: 1.7840, Eval Accuracy: 56.69%, Top-1 Accuracy: 56.69%, Top-5 Accuracy: 82.71%
# Epoch 35/40
# Train Loss: 0.9252, Train Accuracy: 72.59%
# Eval Loss: 1.7487, Eval Accuracy: 56.96%, Top-1 Accuracy: 56.96%, Top-5 Accuracy: 83.36%
# Epoch 36/40
# Train Loss: 0.8796, Train Accuracy: 74.04%
# Eval Loss: 1.7618, Eval Accuracy: 57.42%, Top-1 Accuracy: 57.42%, Top-5 Accuracy: 83.65%
# Epoch 37/40
# Train Loss: 0.8665, Train Accuracy: 74.15%
# Eval Loss: 1.7871, Eval Accuracy: 56.73%, Top-1 Accuracy: 56.73%, Top-5 Accuracy: 83.37%
# Epoch 38/40
# Train Loss: 0.8342, Train Accuracy: 75.34%
# Eval Loss: 1.8171, Eval Accuracy: 56.50%, Top-1 Accuracy: 56.50%, Top-5 Accuracy: 82.42%
# Epoch 39/40
# Train Loss: 0.8104, Train Accuracy: 75.81%
# Eval Loss: 1.8098, Eval Accuracy: 57.04%, Top-1 Accuracy: 57.04%, Top-5 Accuracy: 83.25%
# Epoch 40/40
# Train Loss: 0.7799, Train Accuracy: 76.60%
# Eval Loss: 1.8546, Eval Accuracy: 57.28%, Top-1 Accuracy: 57.28%, Top-5 Accuracy: 82.63%

# %%
# model for custom vgg with addtional drop
class CustomVGG11(nn.Module):
    def __init__(self, num_classes=100, dropout_rate=0.5):
        super(CustomVGG11, self).__init__()
        self.vgg11 = models.vgg11(pretrained=False)
        self.vgg11.classifier = nn.Sequential(
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(True),
            nn.Dropout(dropout_rate),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(dropout_rate),
            nn.Linear(4096, num_classes)
        )
    def forward(self, x):
        return self.vgg11(x)

config = {
    'dataloader': cf100_w_aug,
    'model': CustomVGG11(num_classes=100, dropout_rate=0.5),
    'epochs': 70,
    'optimizer': 'SGD',
    'learning_rate': 0.01,
    'momentum': 0.9,
    'weight_decay': 5e-4,
    'loss': nn.CrossEntropyLoss(),
    'log_dir': os.path.join(BASE_LOGS_PATH, time.strftime('%Y%m%d_%H%M%S') + '_logs'),
    'device': device,
    'run_time': None
}

model = config['model']
model.to(config['device'])
criterion = config['loss']
optimizer = torch.optim.SGD(model.parameters(),
                            lr=config['learning_rate'],
                            momentum=config['momentum'],
                            weight_decay=config['weight_decay'])

if not os.path.exists(config['log_dir']):
    os.makedirs(config['log_dir'])
    print(f"Directory '{config['log_dir']}' created")

metrics_path = os.path.join(config['log_dir'], 'training_metrics.csv')
with open(metrics_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Epoch', 'Train Loss', 'Train Accuracy', 'Eval Loss', 'Eval Accuracy', 'Top-1 Accuracy', 'Top-5 Accuracy', 'Epoch Time (seconds)'])
    for epoch in range(config['epochs']):
        start_time = timeit.default_timer()
        train_losses = []
        train_accuracies = []

        model.train()
        for images, labels in config['dataloader'].train_data_loader:
            images, labels = images.to(config['device']), labels.to(config['device'])
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())
            _, predicted = torch.max(outputs, 1)
            accuracy = (predicted == labels).float().mean().item()
            train_accuracies.append(accuracy)

        eval_losses = []
        eval_accuracies = []
        top1_accuracies = []
        top5_accuracies = []
        model.eval()
        with torch.no_grad():
            for images, labels in config['dataloader'].eval_data_loader:
                images, labels = images.to(config['device']), labels.to(config['device'])
                outputs = model(images)
                loss = criterion(outputs, labels)
                eval_losses.append(loss.item())

                _, predicted = torch.max(outputs, 1)
                top1_accuracy = (predicted == labels).float().mean().item()
                top1_accuracies.append(top1_accuracy)

                _, top5_preds = outputs.topk(5, dim=1)
                top5_correct = top5_preds.eq(labels.view(-1, 1).expand_as(top5_preds))
                top5_accuracy = top5_correct.float().sum(1).ge(1).float().mean().item()
                top5_accuracies.append(top5_accuracy)
                eval_accuracies.append(top1_accuracy)

        end_time = timeit.default_timer()
        epoch_duration = end_time - start_time
        writer.writerow([
            epoch + 1,
            np.mean(train_losses),
            np.mean(train_accuracies) * 100,
            np.mean(eval_losses),
            np.mean(eval_accuracies) * 100,
            np.mean(top1_accuracies) * 100,
            np.mean(top5_accuracies) * 100,
            epoch_duration
        ])
        print(f"Epoch {epoch+1}/{config['epochs']}")
        print(f"Train Loss: {np.mean(train_losses):.4f}, Train Accuracy: {np.mean(train_accuracies) * 100:.2f}%")
        print(f"Eval Loss: {np.mean(eval_losses):.4f}, Eval Accuracy: {np.mean(eval_accuracies) * 100:.2f}%, Top-1 Accuracy: {np.mean(top1_accuracies) * 100:.2f}%, Top-5 Accuracy: {np.mean(top5_accuracies) * 100:.2f}%")


torch.save(model.state_dict(), os.path.join(config['log_dir'], 'model_state_dict.pth'))
torch.save(model, os.path.join(config['log_dir'], 'complete_model.pth'))

config_path = os.path.join(config['log_dir'], 'config.txt')
with open(config_path, 'w') as f:
    for key, value in config.items():
        f.write(f'{key}: {value}\n')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Directory 'drive/MyDrive/DS5220: Final Project/logs/VGG_11/20240425_232158_logs' created
# Epoch 1/40
# Train Loss: 4.5352, Train Accuracy: 1.45%
# Eval Loss: 4.4461, Eval Accuracy: 2.26%, Top-1 Accuracy: 2.26%, Top-5 Accuracy: 10.21%
# Epoch 2/40
# Train Loss: 4.4201, Train Accuracy: 2.36%
# Eval Loss: 4.3186, Eval Accuracy: 4.09%, Top-1 Accuracy: 4.09%, Top-5 Accuracy: 14.97%
# Epoch 3/40
# Train Loss: 4.1597, Train Accuracy: 4.39%
# Eval Loss: 3.9864, Eval Accuracy: 6.71%, Top-1 Accuracy: 6.71%, Top-5 Accuracy: 24.67%
# Epoch 4/40
# Train Loss: 3.9089, Train Accuracy: 7.45%
# Eval Loss: 3.7630, Eval Accuracy: 10.49%, Top-1 Accuracy: 10.49%, Top-5 Accuracy: 33.73%
# Epoch 5/40
# Train Loss: 3.6577, Train Accuracy: 11.55%
# Eval Loss: 3.4658, Eval Accuracy: 15.09%, Top-1 Accuracy: 15.09%, Top-5 Accuracy: 40.89%
# Epoch 6/40
# Train Loss: 3.4197, Train Accuracy: 15.29%
# Eval Loss: 3.2118, Eval Accuracy: 19.59%, Top-1 Accuracy: 19.59%, Top-5 Accuracy: 49.13%
# Epoch 7/40
# Train Loss: 3.2207, Train Accuracy: 19.00%
# Eval Loss: 3.0939, Eval Accuracy: 22.06%, Top-1 Accuracy: 22.06%, Top-5 Accuracy: 51.97%
# Epoch 8/40
# Train Loss: 3.0217, Train Accuracy: 23.04%
# Eval Loss: 2.9130, Eval Accuracy: 25.45%, Top-1 Accuracy: 25.45%, Top-5 Accuracy: 56.74%
# Epoch 9/40
# Train Loss: 2.8407, Train Accuracy: 26.53%
# Eval Loss: 2.6589, Eval Accuracy: 29.85%, Top-1 Accuracy: 29.85%, Top-5 Accuracy: 64.37%
# Epoch 10/40
# Train Loss: 2.6819, Train Accuracy: 30.07%
# Eval Loss: 2.6119, Eval Accuracy: 31.31%, Top-1 Accuracy: 31.31%, Top-5 Accuracy: 64.60%
# Epoch 11/40
# Train Loss: 2.5225, Train Accuracy: 33.41%
# Eval Loss: 2.5648, Eval Accuracy: 33.87%, Top-1 Accuracy: 33.87%, Top-5 Accuracy: 66.29%
# Epoch 12/40
# Train Loss: 2.3995, Train Accuracy: 36.18%
# Eval Loss: 2.2912, Eval Accuracy: 38.42%, Top-1 Accuracy: 38.42%, Top-5 Accuracy: 71.68%
# Epoch 13/40
# Train Loss: 2.2705, Train Accuracy: 38.98%
# Eval Loss: 2.2081, Eval Accuracy: 40.94%, Top-1 Accuracy: 40.94%, Top-5 Accuracy: 72.91%
# Epoch 14/40
# Train Loss: 2.1709, Train Accuracy: 41.51%
# Eval Loss: 2.2374, Eval Accuracy: 40.02%, Top-1 Accuracy: 40.02%, Top-5 Accuracy: 72.65%
# Epoch 15/40
# Train Loss: 2.0805, Train Accuracy: 43.66%
# Eval Loss: 2.0317, Eval Accuracy: 45.58%, Top-1 Accuracy: 45.58%, Top-5 Accuracy: 76.41%
# Epoch 16/40
# Train Loss: 1.9818, Train Accuracy: 45.97%
# Eval Loss: 2.0311, Eval Accuracy: 45.84%, Top-1 Accuracy: 45.84%, Top-5 Accuracy: 76.91%
# Epoch 17/40
# Train Loss: 1.9054, Train Accuracy: 47.88%
# Eval Loss: 1.9559, Eval Accuracy: 47.67%, Top-1 Accuracy: 47.67%, Top-5 Accuracy: 78.22%
# Epoch 18/40
# Train Loss: 1.8256, Train Accuracy: 49.85%
# Eval Loss: 1.8954, Eval Accuracy: 48.82%, Top-1 Accuracy: 48.82%, Top-5 Accuracy: 78.58%
# Epoch 19/40
# Train Loss: 1.7520, Train Accuracy: 51.75%
# Eval Loss: 1.9057, Eval Accuracy: 49.62%, Top-1 Accuracy: 49.62%, Top-5 Accuracy: 79.07%
# Epoch 20/40
# Train Loss: 1.6902, Train Accuracy: 53.14%
# Eval Loss: 1.8267, Eval Accuracy: 50.96%, Top-1 Accuracy: 50.96%, Top-5 Accuracy: 80.35%
# Epoch 21/40
# Train Loss: 1.6315, Train Accuracy: 54.66%
# Eval Loss: 1.8044, Eval Accuracy: 51.12%, Top-1 Accuracy: 51.12%, Top-5 Accuracy: 80.09%
# Epoch 22/40
# Train Loss: 1.5789, Train Accuracy: 55.92%
# Eval Loss: 1.8117, Eval Accuracy: 51.51%, Top-1 Accuracy: 51.51%, Top-5 Accuracy: 80.36%
# Epoch 23/40
# Train Loss: 1.5317, Train Accuracy: 57.09%
# Eval Loss: 1.8043, Eval Accuracy: 51.87%, Top-1 Accuracy: 51.87%, Top-5 Accuracy: 79.89%
# Epoch 24/40
# Train Loss: 1.4709, Train Accuracy: 58.38%
# Eval Loss: 1.7738, Eval Accuracy: 52.85%, Top-1 Accuracy: 52.85%, Top-5 Accuracy: 80.84%
# Epoch 25/40
# Train Loss: 1.4187, Train Accuracy: 59.74%
# Eval Loss: 1.8110, Eval Accuracy: 52.61%, Top-1 Accuracy: 52.61%, Top-5 Accuracy: 81.17%
# Epoch 26/40
# Train Loss: 1.3807, Train Accuracy: 60.96%
# Eval Loss: 1.7547, Eval Accuracy: 54.27%, Top-1 Accuracy: 54.27%, Top-5 Accuracy: 81.45%
# Epoch 27/40
# Train Loss: 1.3224, Train Accuracy: 62.57%
# Eval Loss: 1.7460, Eval Accuracy: 54.50%, Top-1 Accuracy: 54.50%, Top-5 Accuracy: 81.50%
# Epoch 28/40
# Train Loss: 1.2909, Train Accuracy: 63.28%
# Eval Loss: 1.6842, Eval Accuracy: 55.89%, Top-1 Accuracy: 55.89%, Top-5 Accuracy: 82.16%
# Epoch 29/40
# Train Loss: 1.2494, Train Accuracy: 64.36%
# Eval Loss: 1.6961, Eval Accuracy: 55.68%, Top-1 Accuracy: 55.68%, Top-5 Accuracy: 82.77%
# Epoch 30/40
# Train Loss: 1.2062, Train Accuracy: 65.27%
# Eval Loss: 1.7696, Eval Accuracy: 54.36%, Top-1 Accuracy: 54.36%, Top-5 Accuracy: 82.47%
# Epoch 31/40
# Train Loss: 1.1640, Train Accuracy: 66.43%
# Eval Loss: 1.6585, Eval Accuracy: 56.48%, Top-1 Accuracy: 56.48%, Top-5 Accuracy: 83.13%
# Epoch 32/40
# Train Loss: 1.1510, Train Accuracy: 66.73%
# Eval Loss: 1.7145, Eval Accuracy: 55.84%, Top-1 Accuracy: 55.84%, Top-5 Accuracy: 82.49%
# Epoch 33/40
# Train Loss: 1.1017, Train Accuracy: 67.81%
# Eval Loss: 1.7098, Eval Accuracy: 56.20%, Top-1 Accuracy: 56.20%, Top-5 Accuracy: 82.64%
# Epoch 34/40
# Train Loss: 1.0771, Train Accuracy: 68.89%
# Eval Loss: 1.6951, Eval Accuracy: 56.94%, Top-1 Accuracy: 56.94%, Top-5 Accuracy: 83.25%
# Epoch 35/40
# Train Loss: 1.0459, Train Accuracy: 69.57%
# Eval Loss: 1.6892, Eval Accuracy: 57.04%, Top-1 Accuracy: 57.04%, Top-5 Accuracy: 82.64%
# Epoch 36/40
# Train Loss: 1.0305, Train Accuracy: 70.21%
# Eval Loss: 1.7561, Eval Accuracy: 55.60%, Top-1 Accuracy: 55.60%, Top-5 Accuracy: 81.71%
# Epoch 37/40
# Train Loss: 0.9819, Train Accuracy: 71.17%
# Eval Loss: 1.7260, Eval Accuracy: 56.80%, Top-1 Accuracy: 56.80%, Top-5 Accuracy: 83.15%
# Epoch 38/40
# Train Loss: 0.9512, Train Accuracy: 71.95%
# Eval Loss: 1.7285, Eval Accuracy: 56.99%, Top-1 Accuracy: 56.99%, Top-5 Accuracy: 83.03%
# Epoch 39/40
# Train Loss: 0.9292, Train Accuracy: 72.84%
# Eval Loss: 1.7679, Eval Accuracy: 56.75%, Top-1 Accuracy: 56.75%, Top-5 Accuracy: 82.46%
# Epoch 40/40
# Train Loss: 0.8999, Train Accuracy: 73.47%
# Eval Loss: 1.7603, Eval Accuracy: 58.00%, Top-1 Accuracy: 58.00%, Top-5 Accuracy: 83.29%
